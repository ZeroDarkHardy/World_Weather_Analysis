# %% [markdown]
# # Create a new set of 2,000 random latitudes and longitudes

# %%
# Import Dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding cities
cities=[]
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then add it to the list
    if city not in cities:
        cities.append(city)
# print the city count to confirm sufficient data pool size
len(cities)
# Out:
# 765

# %%
# define API URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0132a1a5560f78db4653dca3b1034416

# %%
# Initialize counters and an empty list to hold the weather data
city_data = []
record_count = 1
set_count = 1

# %% [markdown]
# ## Loop through the cities list

# %%
print("Beginning Data Retrieval    ")
print("----------------------------")

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint url with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run the API request for each of the cities:
    try:
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_description = city_weather['weather'][0]['description']
        # Add the parsed data to the list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                         "Lat": city_lat,
                          "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that data loading is complete
print("-------------------------------")
print("Data Retrieval Complete        ")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | oranjestad
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | andenes
# Processing Record 6 of Set 1 | palana
# Processing Record 7 of Set 1 | san carlos de bariloche
# Processing Record 8 of Set 1 | kholm
# Processing Record 9 of Set 1 | kuching
# Processing Record 10 of Set 1 | lompoc
# Processing Record 11 of Set 1 | mizan teferi
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | cockburn town
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | haines junction
# Processing Record 16 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 1 | mayor pablo lagerenza
# Processing Record 18 of Set 1 | puerto leguizamo
# Processing Record 19 of Set 1 | flinders
# Processing Record 20 of Set 1 | port hawkesbury
# Processing Record 21 of Set 1 | conceicao do araguaia
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | luderitz
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | laguna
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | ouango
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | swan river
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | nemuro
# Processing Record 35 of Set 1 | cidreira
# Processing Record 36 of Set 1 | malpe
# Processing Record 37 of Set 1 | fortuna
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | touros
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | christchurch
# Processing Record 43 of Set 1 | kahului
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | korla
# Processing Record 46 of Set 1 | omboue
# Processing Record 47 of Set 1 | meulaboh
# Processing Record 48 of Set 1 | vilyuysk
# Processing Record 49 of Set 1 | marataizes
# Processing Record 50 of Set 1 | san ignacio
# Processing Record 1 of Set 2 | tulum
# Processing Record 2 of Set 2 | chuy
# Processing Record 3 of Set 2 | vanavara
# Processing Record 4 of Set 2 | limerick
# Processing Record 5 of Set 2 | port hardy
# Processing Record 6 of Set 2 | senanga
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | isangel
# Processing Record 9 of Set 2 | bama
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | odweyne
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | beloha
# Processing Record 14 of Set 2 | launceston
# Processing Record 15 of Set 2 | blacksburg
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | krasnozerskoye
# Processing Record 18 of Set 2 | castanos
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | usinsk
# Processing Record 21 of Set 2 | kavaratti
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | sorland
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | middle island
# Processing Record 26 of Set 2 | odienne
# Processing Record 27 of Set 2 | mangrol
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | wanaka
# Processing Record 30 of Set 2 | tandil
# Processing Record 31 of Set 2 | praia
# Processing Record 32 of Set 2 | sisimiut
# Processing Record 33 of Set 2 | manacapuru
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | jalu
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | gat
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | jaque
# Processing Record 49 of Set 2 | krasnokamensk
# Processing Record 50 of Set 2 | iganga
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | zafra
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | paine
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | sumbe
# Processing Record 11 of Set 3 | farafangana
# Processing Record 12 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 3 | pangnirtung
# Processing Record 14 of Set 3 | rio gallegos
# Processing Record 15 of Set 3 | mgandu
# Processing Record 16 of Set 3 | panacan
# Processing Record 17 of Set 3 | keningau
# Processing Record 18 of Set 3 | newport
# Processing Record 19 of Set 3 | santa fe
# Processing Record 20 of Set 3 | bella union
# Processing Record 21 of Set 3 | xai-xai
# Processing Record 22 of Set 3 | tura
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | kemijarvi
# Processing Record 25 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 3 | dabat
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | punta arenas
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | hamilton
# Processing Record 34 of Set 3 | narang
# Processing Record 35 of Set 3 | port hedland
# Processing Record 36 of Set 3 | lemesos
# City not found. Skipping...
# Processing Record 37 of Set 3 | buraydah
# Processing Record 38 of Set 3 | hobart
# Processing Record 39 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 3 | lata
# Processing Record 41 of Set 3 | shache
# Processing Record 42 of Set 3 | quatre cocos
# Processing Record 43 of Set 3 | ajdabiya
# Processing Record 44 of Set 3 | kidero
# Processing Record 45 of Set 3 | saint-augustin
# Processing Record 46 of Set 3 | kaitangata
# Processing Record 47 of Set 3 | san jose
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | bambous virieux
# Processing Record 50 of Set 3 | bulgan
# Processing Record 1 of Set 4 | broken hill
# Processing Record 2 of Set 4 | ahome
# Processing Record 3 of Set 4 | florida
# Processing Record 4 of Set 4 | kodiak
# Processing Record 5 of Set 4 | mackenzie
# Processing Record 6 of Set 4 | santa rosalia
# Processing Record 7 of Set 4 | vao
# Processing Record 8 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 4 | qaanaaq
# Processing Record 11 of Set 4 | lukovetskiy
# Processing Record 12 of Set 4 | pedernales
# Processing Record 13 of Set 4 | san ramon
# Processing Record 14 of Set 4 | nanaimo
# Processing Record 15 of Set 4 | khorixas
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | severodvinsk
# Processing Record 18 of Set 4 | biak
# Processing Record 19 of Set 4 | longjiang
# Processing Record 20 of Set 4 | mar del plata
# Processing Record 21 of Set 4 | esperance
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | cape town
# Processing Record 24 of Set 4 | tilichiki
# Processing Record 25 of Set 4 | fairbanks
# Processing Record 26 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 4 | barcarena
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | mayuge
# Processing Record 30 of Set 4 | port alfred
# Processing Record 31 of Set 4 | hay river
# Processing Record 32 of Set 4 | dawei
# Processing Record 33 of Set 4 | kijang
# Processing Record 34 of Set 4 | cangzhou
# Processing Record 35 of Set 4 | soria
# Processing Record 36 of Set 4 | horasan
# Processing Record 37 of Set 4 | kemin
# Processing Record 38 of Set 4 | noumea
# Processing Record 39 of Set 4 | alofi
# Processing Record 40 of Set 4 | florianopolis
# Processing Record 41 of Set 4 | lakatoro
# Processing Record 42 of Set 4 | kalevala
# Processing Record 43 of Set 4 | narsaq
# Processing Record 44 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | bogande
# Processing Record 46 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | acapulco
# Processing Record 49 of Set 4 | morros
# Processing Record 50 of Set 4 | bac lieu
# Processing Record 1 of Set 5 | urusha
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | kastamonu
# Processing Record 5 of Set 5 | ahtopol
# Processing Record 6 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 5 | la ronge
# Processing Record 8 of Set 5 | whitehorse
# Processing Record 9 of Set 5 | kaeo
# Processing Record 10 of Set 5 | oistins
# Processing Record 11 of Set 5 | benghazi
# Processing Record 12 of Set 5 | marfino
# Processing Record 13 of Set 5 | tuktoyaktuk
# Processing Record 14 of Set 5 | altea
# Processing Record 15 of Set 5 | saskylakh
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | hambantota
# Processing Record 18 of Set 5 | ketchikan
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | seoul
# Processing Record 21 of Set 5 | kirakira
# Processing Record 22 of Set 5 | tyret pervaya
# Processing Record 23 of Set 5 | qarqin
# Processing Record 24 of Set 5 | lufilufi
# Processing Record 25 of Set 5 | vardo
# Processing Record 26 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 5 | vestmannaeyjar
# Processing Record 28 of Set 5 | victoria
# Processing Record 29 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 5 | champerico
# Processing Record 31 of Set 5 | batagay
# Processing Record 32 of Set 5 | marawi
# Processing Record 33 of Set 5 | kutum
# Processing Record 34 of Set 5 | qaqortoq
# Processing Record 35 of Set 5 | adeje
# Processing Record 36 of Set 5 | beringovskiy
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | alghero
# Processing Record 39 of Set 5 | aloleng
# Processing Record 40 of Set 5 | roebourne
# Processing Record 41 of Set 5 | marathon
# Processing Record 42 of Set 5 | taoudenni
# Processing Record 43 of Set 5 | praia da vitoria
# Processing Record 44 of Set 5 | paita
# Processing Record 45 of Set 5 | hofn
# Processing Record 46 of Set 5 | adrar
# Processing Record 47 of Set 5 | imeni poliny osipenko
# Processing Record 48 of Set 5 | senno
# Processing Record 49 of Set 5 | saint anthony
# Processing Record 50 of Set 5 | prince rupert
# Processing Record 1 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 6 | doha
# Processing Record 3 of Set 6 | imbituba
# Processing Record 4 of Set 6 | namibe
# Processing Record 5 of Set 6 | faya
# Processing Record 6 of Set 6 | bonavista
# Processing Record 7 of Set 6 | huarmey
# Processing Record 8 of Set 6 | noyabrsk
# Processing Record 9 of Set 6 | padang
# Processing Record 10 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 6 | fez
# Processing Record 12 of Set 6 | bere
# Processing Record 13 of Set 6 | salym
# Processing Record 14 of Set 6 | pinega
# Processing Record 15 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | cabo san lucas
# Processing Record 17 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 6 | shumerlya
# Processing Record 20 of Set 6 | sitka
# Processing Record 21 of Set 6 | ponta do sol
# Processing Record 22 of Set 6 | iranshahr
# Processing Record 23 of Set 6 | mount isa
# Processing Record 24 of Set 6 | torbay
# Processing Record 25 of Set 6 | morant bay
# Processing Record 26 of Set 6 | belle fourche
# Processing Record 27 of Set 6 | balkhash
# Processing Record 28 of Set 6 | marsa matruh
# Processing Record 29 of Set 6 | kolokani
# Processing Record 30 of Set 6 | vinukonda
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | garden city
# Processing Record 33 of Set 6 | port blair
# Processing Record 34 of Set 6 | elat
# Processing Record 35 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 37 of Set 6 | villa carlos paz
# Processing Record 38 of Set 6 | kupang
# Processing Record 39 of Set 6 | magistralnyy
# Processing Record 40 of Set 6 | klaksvik
# Processing Record 41 of Set 6 | bosaso
# Processing Record 42 of Set 6 | lima
# Processing Record 43 of Set 6 | igarka
# Processing Record 44 of Set 6 | tchollire
# Processing Record 45 of Set 6 | comodoro rivadavia
# Processing Record 46 of Set 6 | nikolskoye
# Processing Record 47 of Set 6 | cilegon
# Processing Record 48 of Set 6 | sebrovo
# Processing Record 49 of Set 6 | tuatapere
# Processing Record 50 of Set 6 | mildura
# Processing Record 1 of Set 7 | grindavik
# Processing Record 2 of Set 7 | kruisfontein
# Processing Record 3 of Set 7 | vaitape
# Processing Record 4 of Set 7 | camacha
# Processing Record 5 of Set 7 | lahat
# Processing Record 6 of Set 7 | ternate
# Processing Record 7 of Set 7 | buala
# Processing Record 8 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 7 | bajil
# Processing Record 10 of Set 7 | mocuba
# Processing Record 11 of Set 7 | leningradskiy
# Processing Record 12 of Set 7 | freeport
# Processing Record 13 of Set 7 | shieli
# Processing Record 14 of Set 7 | muisne
# Processing Record 15 of Set 7 | lucea
# Processing Record 16 of Set 7 | apodi
# Processing Record 17 of Set 7 | pemangkat
# Processing Record 18 of Set 7 | kosa
# Processing Record 19 of Set 7 | honiara
# Processing Record 20 of Set 7 | ca mau
# Processing Record 21 of Set 7 | phuket
# Processing Record 22 of Set 7 | grand-santi
# Processing Record 23 of Set 7 | lavrentiya
# Processing Record 24 of Set 7 | kiama
# Processing Record 25 of Set 7 | pekalongan
# Processing Record 26 of Set 7 | novoilinsk
# Processing Record 27 of Set 7 | methven
# Processing Record 28 of Set 7 | gizo
# Processing Record 29 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 7 | matagami
# Processing Record 31 of Set 7 | yulara
# Processing Record 32 of Set 7 | fremont
# Processing Record 33 of Set 7 | lazo
# Processing Record 34 of Set 7 | ostrovnoy
# Processing Record 35 of Set 7 | wanxian
# Processing Record 36 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 7 | sao jose da coroa grande
# Processing Record 38 of Set 7 | labuan
# Processing Record 39 of Set 7 | posse
# Processing Record 40 of Set 7 | henties bay
# Processing Record 41 of Set 7 | suntar
# Processing Record 42 of Set 7 | trojes
# Processing Record 43 of Set 7 | richards bay
# Processing Record 44 of Set 7 | brae
# Processing Record 45 of Set 7 | nhulunbuy
# Processing Record 46 of Set 7 | gisborne
# Processing Record 47 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 48 of Set 7 | mezen
# Processing Record 49 of Set 7 | camana
# Processing Record 50 of Set 7 | eyemouth
# Processing Record 1 of Set 8 | yoichi
# Processing Record 2 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 8 | irbeyskoye
# Processing Record 4 of Set 8 | sechura
# Processing Record 5 of Set 8 | shagonar
# Processing Record 6 of Set 8 | chongoyape
# Processing Record 7 of Set 8 | ardakan
# Processing Record 8 of Set 8 | rio cuarto
# Processing Record 9 of Set 8 | monticello
# Processing Record 10 of Set 8 | katherine
# Processing Record 11 of Set 8 | nabire
# Processing Record 12 of Set 8 | mackay
# Processing Record 13 of Set 8 | asau
# Processing Record 14 of Set 8 | thilogne
# City not found. Skipping...
# Processing Record 15 of Set 8 | puerto madryn
# Processing Record 16 of Set 8 | bengkulu
# Processing Record 17 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 18 of Set 8 | avarua
# Processing Record 19 of Set 8 | ancud
# Processing Record 20 of Set 8 | merrill
# Processing Record 21 of Set 8 | general roca
# Processing Record 22 of Set 8 | mozarlandia
# Processing Record 23 of Set 8 | coquimbo
# Processing Record 24 of Set 8 | puerto carreno
# Processing Record 25 of Set 8 | ovalle
# Processing Record 26 of Set 8 | sambava
# Processing Record 27 of Set 8 | poum
# Processing Record 28 of Set 8 | show low
# Processing Record 29 of Set 8 | uchiza
# Processing Record 30 of Set 8 | saint-joseph
# Processing Record 31 of Set 8 | jingdezhen
# Processing Record 32 of Set 8 | mamlyutka
# Processing Record 33 of Set 8 | umba
# Processing Record 34 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 35 of Set 8 | dingle
# Processing Record 36 of Set 8 | talnakh
# Processing Record 37 of Set 8 | aksarka
# Processing Record 38 of Set 8 | omsukchan
# Processing Record 39 of Set 8 | hualmay
# Processing Record 40 of Set 8 | bjelovar
# Processing Record 41 of Set 8 | tefe
# Processing Record 42 of Set 8 | mahibadhoo
# Processing Record 43 of Set 8 | casper
# Processing Record 44 of Set 8 | caxito
# Processing Record 45 of Set 8 | shebunino
# Processing Record 46 of Set 8 | cam ranh
# Processing Record 47 of Set 8 | vasai
# Processing Record 48 of Set 8 | karratha
# Processing Record 49 of Set 8 | te anau
# Processing Record 50 of Set 8 | huazolotitlan
# City not found. Skipping...
# Processing Record 1 of Set 9 | lisakovsk
# Processing Record 2 of Set 9 | liaoyang
# Processing Record 3 of Set 9 | kununurra
# Processing Record 4 of Set 9 | vila velha
# Processing Record 5 of Set 9 | eirunepe
# Processing Record 6 of Set 9 | lyuban
# Processing Record 7 of Set 9 | hajdudorog
# Processing Record 8 of Set 9 | moussoro
# Processing Record 9 of Set 9 | bar harbor
# Processing Record 10 of Set 9 | mount gambier
# Processing Record 11 of Set 9 | muros
# Processing Record 12 of Set 9 | marzuq
# Processing Record 13 of Set 9 | ulverstone
# Processing Record 14 of Set 9 | puerto palomas
# Processing Record 15 of Set 9 | le port
# Processing Record 16 of Set 9 | iqaluit
# Processing Record 17 of Set 9 | mersin
# Processing Record 18 of Set 9 | sabang
# Processing Record 19 of Set 9 | nong kung si
# Processing Record 20 of Set 9 | coihaique
# Processing Record 21 of Set 9 | jishou
# Processing Record 22 of Set 9 | san cristobal
# Processing Record 23 of Set 9 | karabulak
# Processing Record 24 of Set 9 | myingyan
# Processing Record 25 of Set 9 | palembang
# Processing Record 26 of Set 9 | broome
# Processing Record 27 of Set 9 | kamenka
# Processing Record 28 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 29 of Set 9 | rafai
# Processing Record 30 of Set 9 | villeneuve-sur-lot
# Processing Record 31 of Set 9 | oyama
# Processing Record 32 of Set 9 | sakakah
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | cayambe
# Processing Record 35 of Set 9 | gilgit
# Processing Record 36 of Set 9 | faanui
# Processing Record 37 of Set 9 | ulaangom
# Processing Record 38 of Set 9 | ducheng
# Processing Record 39 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 9 | shellbrook
# Processing Record 41 of Set 9 | vuktyl
# Processing Record 42 of Set 9 | taltal
# Processing Record 43 of Set 9 | gardony
# Processing Record 44 of Set 9 | moiyabana
# City not found. Skipping...
# Processing Record 45 of Set 9 | meadow lake
# Processing Record 46 of Set 9 | turayf
# Processing Record 47 of Set 9 | fort walton beach
# Processing Record 48 of Set 9 | moerai
# Processing Record 49 of Set 9 | roald
# Processing Record 50 of Set 9 | karangsembung
# Processing Record 1 of Set 10 | lubbock
# Processing Record 2 of Set 10 | pecos
# Processing Record 3 of Set 10 | nadym
# Processing Record 4 of Set 10 | kotma
# Processing Record 5 of Set 10 | jaciara
# Processing Record 6 of Set 10 | tombouctou
# Processing Record 7 of Set 10 | namatanai
# Processing Record 8 of Set 10 | tezu
# Processing Record 9 of Set 10 | osterhofen
# Processing Record 10 of Set 10 | de-kastri
# Processing Record 11 of Set 10 | ocos
# Processing Record 12 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 10 | townsville
# Processing Record 14 of Set 10 | umea
# Processing Record 15 of Set 10 | muriwai beach
# Processing Record 16 of Set 10 | corinto
# Processing Record 17 of Set 10 | yerbogachen
# Processing Record 18 of Set 10 | ahipara
# Processing Record 19 of Set 10 | beya
# Processing Record 20 of Set 10 | grants
# Processing Record 21 of Set 10 | kashi
# Processing Record 22 of Set 10 | rietavas
# Processing Record 23 of Set 10 | puerto escondido
# Processing Record 24 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 10 | coos bay
# Processing Record 26 of Set 10 | tindwari
# Processing Record 27 of Set 10 | port-gentil
# Processing Record 28 of Set 10 | storforshei
# Processing Record 29 of Set 10 | mbulu
# Processing Record 30 of Set 10 | samfya
# Processing Record 31 of Set 10 | abu samrah
# Processing Record 32 of Set 10 | victoria point
# Processing Record 33 of Set 10 | maumere
# Processing Record 34 of Set 10 | breza
# Processing Record 35 of Set 10 | safford
# Processing Record 36 of Set 10 | riyadh
# Processing Record 37 of Set 10 | harper
# Processing Record 38 of Set 10 | kurbnesh
# Processing Record 39 of Set 10 | mahon
# Processing Record 40 of Set 10 | sao joao da barra
# Processing Record 41 of Set 10 | yazd
# Processing Record 42 of Set 10 | auki
# Processing Record 43 of Set 10 | marsh harbour
# Processing Record 44 of Set 10 | natal
# Processing Record 45 of Set 10 | xiamen
# Processing Record 46 of Set 10 | cayenne
# Processing Record 47 of Set 10 | radstadt
# Processing Record 48 of Set 10 | caldas novas
# Processing Record 49 of Set 10 | wanning
# Processing Record 50 of Set 10 | yar-sale
# Processing Record 1 of Set 11 | ilheus
# Processing Record 2 of Set 11 | ati
# Processing Record 3 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 11 | warri
# Processing Record 5 of Set 11 | birao
# Processing Record 6 of Set 11 | thinadhoo
# Processing Record 7 of Set 11 | puerto suarez
# Processing Record 8 of Set 11 | kieta
# Processing Record 9 of Set 11 | acopiara
# Processing Record 10 of Set 11 | yeniseysk
# Processing Record 11 of Set 11 | tartki
# City not found. Skipping...
# Processing Record 12 of Set 11 | mananjary
# Processing Record 13 of Set 11 | capreol
# Processing Record 14 of Set 11 | concepcion
# Processing Record 15 of Set 11 | inhambane
# Processing Record 16 of Set 11 | chara
# Processing Record 17 of Set 11 | zavet
# Processing Record 18 of Set 11 | eureka
# Processing Record 19 of Set 11 | naze
# Processing Record 20 of Set 11 | kalikino
# Processing Record 21 of Set 11 | murgab
# Processing Record 22 of Set 11 | manapparai
# Processing Record 23 of Set 11 | baghdad
# Processing Record 24 of Set 11 | hobyo
# Processing Record 25 of Set 11 | ofunato
# Processing Record 26 of Set 11 | acari
# Processing Record 27 of Set 11 | yanam
# Processing Record 28 of Set 11 | alcaudete
# Processing Record 29 of Set 11 | umm lajj
# Processing Record 30 of Set 11 | shangrao
# Processing Record 31 of Set 11 | kindu
# Processing Record 32 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 11 | kloulklubed
# Processing Record 34 of Set 11 | sinop
# Processing Record 35 of Set 11 | kaohsiung
# Processing Record 36 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 11 | walvis bay
# Processing Record 38 of Set 11 | paamiut
# Processing Record 39 of Set 11 | wasilla
# Processing Record 40 of Set 11 | jibuti
# Processing Record 41 of Set 11 | puerto ayacucho
# Processing Record 42 of Set 11 | ngama
# Processing Record 43 of Set 11 | jinxiang
# Processing Record 44 of Set 11 | benguela
# Processing Record 45 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 11 | kortkeros
# Processing Record 47 of Set 11 | cervo
# Processing Record 48 of Set 11 | zyryanka
# Processing Record 49 of Set 11 | ibra
# Processing Record 50 of Set 11 | vila do maio
# Processing Record 1 of Set 12 | yenagoa
# Processing Record 2 of Set 12 | kurya
# Processing Record 3 of Set 12 | sur
# Processing Record 4 of Set 12 | lamu
# Processing Record 5 of Set 12 | hazaribag
# Processing Record 6 of Set 12 | sola
# Processing Record 7 of Set 12 | tokonou
# Processing Record 8 of Set 12 | lingsugur
# Processing Record 9 of Set 12 | byron bay
# Processing Record 10 of Set 12 | pevek
# Processing Record 11 of Set 12 | sabha
# Processing Record 12 of Set 12 | yongan
# Processing Record 13 of Set 12 | upington
# Processing Record 14 of Set 12 | sakaiminato
# Processing Record 15 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 12 | tenosique
# Processing Record 17 of Set 12 | ust-kulom
# Processing Record 18 of Set 12 | caravelas
# Processing Record 19 of Set 12 | dzhebariki-khaya
# Processing Record 20 of Set 12 | vostok
# Processing Record 21 of Set 12 | san quintin
# Processing Record 22 of Set 12 | tulun
# Processing Record 23 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 24 of Set 12 | banjar
# Processing Record 25 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 12 | awjilah
# Processing Record 27 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 28 of Set 12 | nishihara
# Processing Record 29 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 30 of Set 12 | presidente medici
# Processing Record 31 of Set 12 | zabol
# Processing Record 32 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 12 | miles city
# Processing Record 34 of Set 12 | saldanha
# Processing Record 35 of Set 12 | ekangala
# Processing Record 36 of Set 12 | sibi
# Processing Record 37 of Set 12 | ambilobe
# Processing Record 38 of Set 12 | alta floresta
# Processing Record 39 of Set 12 | baracoa
# Processing Record 40 of Set 12 | qena
# Processing Record 41 of Set 12 | lingao
# Processing Record 42 of Set 12 | balikpapan
# Processing Record 43 of Set 12 | kamaishi
# Processing Record 44 of Set 12 | gundorovskiy
# Processing Record 45 of Set 12 | orito
# Processing Record 46 of Set 12 | waki
# Processing Record 47 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 12 | kropotkin
# Processing Record 49 of Set 12 | manaus
# Processing Record 50 of Set 12 | follonica
# Processing Record 1 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 13 | innisfail
# Processing Record 3 of Set 13 | husavik
# Processing Record 4 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 13 | zhigansk
# Processing Record 6 of Set 13 | ismailia
# Processing Record 7 of Set 13 | turkmenabat
# Processing Record 8 of Set 13 | chengmai
# City not found. Skipping...
# Processing Record 9 of Set 13 | portland
# Processing Record 10 of Set 13 | cruzeiro do sul
# Processing Record 11 of Set 13 | birjand
# Processing Record 12 of Set 13 | kesinga
# Processing Record 13 of Set 13 | itapira
# Processing Record 14 of Set 13 | porosozero
# Processing Record 15 of Set 13 | palaikastron
# Processing Record 16 of Set 13 | deputatskiy
# Processing Record 17 of Set 13 | vestmanna
# Processing Record 18 of Set 13 | griffith
# Processing Record 19 of Set 13 | agadez
# Processing Record 20 of Set 13 | dublin
# Processing Record 21 of Set 13 | evensk
# Processing Record 22 of Set 13 | taihe
# Processing Record 23 of Set 13 | manakara
# Processing Record 24 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 13 | yumen
# Processing Record 26 of Set 13 | sambalpur
# Processing Record 27 of Set 13 | peristera
# Processing Record 28 of Set 13 | sinnamary
# Processing Record 29 of Set 13 | liteni
# Processing Record 30 of Set 13 | aksu
# Processing Record 31 of Set 13 | darab
# Processing Record 32 of Set 13 | banda aceh
# Processing Record 33 of Set 13 | luwuk
# Processing Record 34 of Set 13 | tabuk
# Processing Record 35 of Set 13 | san andres
# Processing Record 36 of Set 13 | macamic
# Processing Record 37 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 13 | levelland
# Processing Record 39 of Set 13 | asyut
# Processing Record 40 of Set 13 | japura
# Processing Record 41 of Set 13 | solnechnyy
# Processing Record 42 of Set 13 | guayaramerin
# Processing Record 43 of Set 13 | tenenkou
# Processing Record 44 of Set 13 | ponta delgada
# Processing Record 45 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 46 of Set 13 | viedma
# Processing Record 47 of Set 13 | kaoma
# Processing Record 48 of Set 13 | nantucket
# Processing Record 49 of Set 13 | mehamn
# Processing Record 50 of Set 13 | norwalk
# Processing Record 1 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 14 | longido
# Processing Record 3 of Set 14 | arlit
# Processing Record 4 of Set 14 | surt
# Processing Record 5 of Set 14 | blucina
# Processing Record 6 of Set 14 | sao felix do xingu
# Processing Record 7 of Set 14 | mahenge
# Processing Record 8 of Set 14 | garavuti
# Processing Record 9 of Set 14 | guerrero negro
# Processing Record 10 of Set 14 | grand gaube
# Processing Record 11 of Set 14 | salalah
# Processing Record 12 of Set 14 | matara
# Processing Record 13 of Set 14 | baykit
# Processing Record 14 of Set 14 | makat
# Processing Record 15 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 16 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 14 | frontera
# Processing Record 18 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 14 | chapais
# Processing Record 20 of Set 14 | abeche
# Processing Record 21 of Set 14 | mahajanga
# Processing Record 22 of Set 14 | laguna de perlas
# Processing Record 23 of Set 14 | tiarei
# Processing Record 24 of Set 14 | yinchuan
# Processing Record 25 of Set 14 | teguise
# Processing Record 26 of Set 14 | kokopo
# Processing Record 27 of Set 14 | micheweni
# Processing Record 28 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 29 of Set 14 | sangar
# Processing Record 30 of Set 14 | sivaki
# Processing Record 31 of Set 14 | puebloviejo
# Processing Record 32 of Set 14 | ust-ilimsk
# Processing Record 33 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 14 | bumba
# Processing Record 35 of Set 14 | staryy krym
# Processing Record 36 of Set 14 | ceska ves
# Processing Record 37 of Set 14 | terny
# Processing Record 38 of Set 14 | ewa beach
# Processing Record 39 of Set 14 | karksi-nuia
# Processing Record 40 of Set 14 | kobojango
# City not found. Skipping...
# Processing Record 41 of Set 14 | zelenogradsk
# Processing Record 42 of Set 14 | coyah
# Processing Record 43 of Set 14 | alyangula
# Processing Record 44 of Set 14 | avera
# Processing Record 45 of Set 14 | carutapera
# Processing Record 46 of Set 14 | kiomboi
# Processing Record 47 of Set 14 | san lawrenz
# Processing Record 48 of Set 14 | veraval
# Processing Record 49 of Set 14 | tigil
# Processing Record 50 of Set 14 | abu dhabi
# Processing Record 1 of Set 15 | opuwo
# Processing Record 2 of Set 15 | port lavaca
# Processing Record 3 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 15 | tessalit
# Processing Record 5 of Set 15 | les cayes
# Processing Record 6 of Set 15 | xuddur
# Processing Record 7 of Set 15 | kavarna
# Processing Record 8 of Set 15 | dormidontovka
# Processing Record 9 of Set 15 | henderson
# Processing Record 10 of Set 15 | williston
# Processing Record 11 of Set 15 | san borja
# Processing Record 12 of Set 15 | vanimo
# Processing Record 13 of Set 15 | durban
# Processing Record 14 of Set 15 | raciborz
# Processing Record 15 of Set 15 | villaviciosa
# Processing Record 16 of Set 15 | severnyy
# Processing Record 17 of Set 15 | cabedelo
# Processing Record 18 of Set 15 | arkhara
# Processing Record 19 of Set 15 | valparaiso
# Processing Record 20 of Set 15 | tachi
# City not found. Skipping...
# Processing Record 21 of Set 15 | dumas
# Processing Record 22 of Set 15 | warragul
# Processing Record 23 of Set 15 | sirjan
# Processing Record 24 of Set 15 | the valley
# Processing Record 25 of Set 15 | saint-denis
# Processing Record 26 of Set 15 | presidencia roque saenz pena
# Processing Record 27 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 15 | margate
# Processing Record 29 of Set 15 | talaya
# Processing Record 30 of Set 15 | atar
# Processing Record 31 of Set 15 | vagamo
# Processing Record 32 of Set 15 | shingu
# Processing Record 33 of Set 15 | zwettl
# Processing Record 34 of Set 15 | lodwar
# Processing Record 35 of Set 15 | constantine
# Processing Record 36 of Set 15 | gillette
# Processing Record 37 of Set 15 | san patricio
# Processing Record 38 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 15 | america dourada
# Processing Record 40 of Set 15 | belmonte
# Processing Record 41 of Set 15 | goundam
# Processing Record 42 of Set 15 | minnedosa
# Processing Record 43 of Set 15 | ryotsu
# Processing Record 44 of Set 15 | charters towers
# Processing Record 45 of Set 15 | minas
# Processing Record 46 of Set 15 | lydenburg
# Processing Record 47 of Set 15 | bida
# Processing Record 48 of Set 15 | san vicente
# Processing Record 49 of Set 15 | navahrudak
# Processing Record 50 of Set 15 | ayagoz
# Processing Record 1 of Set 16 | nushki
# Processing Record 2 of Set 16 | balabac
# Processing Record 3 of Set 16 | bandarbeyla
# Processing Record 4 of Set 16 | westerland
# Processing Record 5 of Set 16 | olafsvik
# Processing Record 6 of Set 16 | lasa
# Processing Record 7 of Set 16 | lazurne
# Processing Record 8 of Set 16 | bilibino
# Processing Record 9 of Set 16 | fenoarivo
# Processing Record 10 of Set 16 | aden
# Processing Record 11 of Set 16 | tingo maria
# Processing Record 12 of Set 16 | staryy nadym
# Processing Record 13 of Set 16 | kathmandu
# Processing Record 14 of Set 16 | kulevcha
# Processing Record 15 of Set 16 | halalo
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Check length of list to ensure proper data pool size
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Convert the array of dictionaries into a pandas dataframe

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Albany      US  42.6001  -73.9662     36.18        72
# 1               Oranjestad      AW  12.5240  -70.0270     85.95        66
# 2                  Rikitea      PF -23.1203 -134.9692     76.44        75
# 3                   Dikson      RU  73.5069   80.5464    -13.23       100
# 4                  Andenes      NO  69.3143   16.1194     19.38        68
# 5                   Palana      RU  59.1167  159.9667     18.09        71
# 6  San Carlos De Bariloche      AR -41.1456  -71.3082     74.95        16
# 7                    Kholm      RU  59.2667   32.8500     25.95        96
# 8                  Kuching      MY   1.5500  110.3333     77.22        94
# 9                   Lompoc      US  34.6391 -120.4579     90.10        39
#
#    Cloudiness  Wind Speed Current Description
# 0         100        2.35     overcast clouds
# 1          40       17.27    scattered clouds
# 2           0       21.07           clear sky
# 3         100        8.41     overcast clouds
# 4          20        6.91          few clouds
# 5         100       28.77          light snow
# 6          20       25.32          few clouds
# 7         100        9.48                snow
# 8          20        2.30          few clouds
# 9           1       11.50           clear sky

# %%
# create the output file
output_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
